# %% [markdown]
# # K-Means Clustering

# %% [markdown]
# ### Langkah Pertama : Pahami dataset

# %% [markdown]
# Import keperluan library untuk mengolah dan menampilkan dataset

# %%
import pandas as pd

# %% [markdown]
# Meload data dan mengubah data nya ke numpy array

# %%
dataTrain = pd.read_csv('TrainingSet.txt', delimiter='\t').as_matrix()
dataTrain
# Out:
# array([[ 21.3 ,  20.8 ],
#        [ 20.15,  20.9 ],
#        [ 19.2 ,  21.35],
#        ...,
#        [  8.8 ,  11.4 ],
#        [  9.  ,  10.9 ],
#        [  9.35,  10.5 ]])

# %% [markdown]
# Melakukan visualisasi data dengan pyplot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(dataTrain[:,0],dataTrain[:,1]) # dataTrain[:,0] mengambil kolom X, sedangkan [:,1] mengambil kolom Y
plt.title('Scatter Plot')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# Hasil datasetnya adalah seperti di tabel scatter plot diatas, hmm menurut penglihatan amatir saya, sepertinya bisa menjadi 7 cluster

# %% [markdown]
# Menghitung Euclidean

# %%
def euclidean(a,b):
    return np.linalg.norm(a-b)

# %% [markdown]
# Menggunakan Library Sci-Kit Learn untuk membantu menentukan jumlah cluster

# %%
from sklearn.cluster import KMeans
sse = []
for i in range(1,10):
    kmeans = KMeans(n_clusters = i, init ='k-means++', max_iter = 300, n_init = 10, random_state =0)
    kmeans.fit(dataTrain)
    sse.append(kmeans.inertia_)
plt.plot(range(1,10), sse)
plt.title('Elbow Method')
plt.xlabel('Jumlah Cluster')
plt.ylabel('SSE')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
def getCentroid(data, k):
    index = np.random.randint(0,data.shape[0],k) # memilih index random, sebanyak 2 data
    return data[index] # memotong array data berdasarkan index yang terpilih

print(pilihCentroid(dataTrain, 3))
# Out:
# [[ 14.15  28.8 ]
#  [  8.3   19.45]
#  [ 21.3   20.8 ]]

# %%
import numpy as np
dataTrain[np.random.randint(0,dataTrain.shape[0],2)]
# Out:
# array([[ 19.2 ,  23.7 ],
#        [ 11.25,  27.4 ]])

# %%
# b = np.random.randint(0,dataTrain.shape[0],2) # memilih index random, sebanyak 2 data
b = np.random.randint(0,100,4)

b
# Out:
# array([48, 38, 95, 49])
